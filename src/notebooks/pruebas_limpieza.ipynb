# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import bootcampviztools as viz
import ToolBox as tb
import re

from scipy.io import arff

# %%
data, meta = arff.loadarff("./data/speed_dating.arff")
meta
# Out:
# Dataset: 'Speed
# 	has_null's type is nominal, range is ('0', '1')
# 	wave's type is numeric
# 	gender's type is nominal, range is ('female', 'male')
# 	age's type is numeric
# 	age_o's type is numeric
# 	d_age's type is numeric
# 	d_d_age's type is nominal, range is ('[4-6]', '[0-1]', '[2-3]', '[7-37]')
# 	race's type is nominal, range is ('Asian/Pacific Islander/Asian-American', 'European/Caucasian-American', 'Other', 'Latino/Hispanic American', 'Black/African American')
# 	race_o's type is nominal, range is ('European/Caucasian-American', 'Asian/Pacific Islander/Asian-American', 'Latino/Hispanic American', 'Other', 'Black/African American')
# 	samerace's type is nominal, range is ('0', '1')
# 	importance_same_race's type is numeric
# 	importance_same_religion's type is numeric
# 	d_importance_same_race's type is nominal, range is ('[2-5]', '[6-10]', '[0-1]')
# 	d_importance_same_religion's type is nominal, range is ('[2-5]', '[0-1]', '[6-10]')
# ...

# %%
data
# Out:
# array([(b'0',  1., b'female', 21., 27., 6., b'[4-6]', b'Asian/Pacific Islander/Asian-American', b'European/Caucasian-American', b'0', 2., 4., b'[2-5]', b'[2-5]', b'Law', 35., 20., 20., 20.,  0.,  5., b'[21-100]', b'[16-20]', b'[16-20]', b'[16-20]', b'[0-15]', b'[0-15]',  6.,  8.,  8.,  8.,  8.,  6., b'[6-8]', b'[6-8]', b'[6-8]', b'[6-8]', b'[6-8]', b'[6-8]', 15., 20., 20., 15., 15., 15., b'[0-15]', b'[16-20]', b'[16-20]', b'[0-15]', b'[0-15]', b'[0-15]', 6., 8., 8., 8., 7., b'[6-8]', b'[6-8]', b'[6-8]', b'[6-8]', b'[6-8]', 6., 9., 7., 7.,  6.,  5., b'[6-8]', b'[9-10]', b'[6-8]', b'[6-8]', b'[6-8]', b'[0-5]', 9., 2., 8.,  9.,  1.,  1., 5., 1., 5., 6., 9., 1., 10., 10.,  9., 8., 1., b'[9-10]', b'[0-5]', b'[6-8]', b'[9-10]', b'[0-5]', b'[0-5]', b'[0-5]', b'[0-5]', b'[0-5]', b'[6-8]', b'[9-10]', b'[0-5]', b'[9-10]', b'[9-10]', b'[9-10]', b'[6-8]', b'[0-5]',  0.14, b'[0-0.33]',  3.,  2., 4., b'[0-4]', b'[0-3]', b'[3-5]', 7.,  6., b'[6-8]', b'[5-6]', 0., b'1', b'0', b'0'),
# ...

# %%
pd.set_option("display.max_columns", None)
df = pd.DataFrame(data)
df
# Out:
#      has_null  wave     gender   age  age_o  d_age   d_d_age  \
# 0        b'0'   1.0  b'female'  21.0   27.0    6.0  b'[4-6]'
# 1        b'0'   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 2        b'1'   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 3        b'0'   1.0  b'female'  21.0   23.0    2.0  b'[2-3]'
# 4        b'0'   1.0  b'female'  21.0   24.0    3.0  b'[2-3]'
# ...       ...   ...        ...   ...    ...    ...       ...
# 8373     b'1'  21.0    b'male'  25.0   26.0    1.0  b'[0-1]'
# 8374     b'1'  21.0    b'male'  25.0   24.0    1.0  b'[0-1]'
# 8375     b'1'  21.0    b'male'  25.0   29.0    4.0  b'[4-6]'
# 8376     b'1'  21.0    b'male'  25.0   22.0    3.0  b'[2-3]'
# 8377     b'1'  21.0    b'male'  25.0   22.0    3.0  b'[2-3]'
#
#                                           race  \
# 0     b'Asian/Pacific Islander/Asian-American'
# 1     b'Asian/Pacific Islander/Asian-American'
# 2     b'Asian/Pacific Islander/Asian-American'
# ...

# %%
df.dtypes
# Out:
# has_null               object
# wave                  float64
# gender                 object
# age                   float64
# age_o                 float64
#                        ...
# d_guess_prob_liked     object
# met                   float64
# decision               object
# decision_o             object
# match                  object
# Length: 123, dtype: object

# %%
df.has_null.astype(int)
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 8373    1
# 8374    1
# 8375    1
# 8376    1
# 8377    1
# Name: has_null, Length: 8378, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# object     64
# float64    59
# Name: count, dtype: int64

# %%
for col in df:
    if df[col].dtype == object:
        try:
            df[col] = df[col].astype(int)
        except:
            df[col] = df[col].astype(str)

# %%
df.dtypes.value_counts()
# Out:
# float64    59
# object     59
# int64       5
# Name: count, dtype: int64

# %%
df.loc[:, [col for col in df.columns if df[col].dtype == object]]
# Out:
#       gender d_d_age                                   race  \
# 0     female   [4-6]  Asian/Pacific Islander/Asian-American
# 1     female   [0-1]  Asian/Pacific Islander/Asian-American
# 2     female   [0-1]  Asian/Pacific Islander/Asian-American
# 3     female   [2-3]  Asian/Pacific Islander/Asian-American
# 4     female   [2-3]  Asian/Pacific Islander/Asian-American
# ...      ...     ...                                    ...
# 8373    male   [0-1]            European/Caucasian-American
# 8374    male   [0-1]            European/Caucasian-American
# 8375    male   [4-6]            European/Caucasian-American
# 8376    male   [2-3]            European/Caucasian-American
# 8377    male   [2-3]            European/Caucasian-American
#
#                                      race_o d_importance_same_race  \
# 0               European/Caucasian-American                  [2-5]
# 1               European/Caucasian-American                  [2-5]
# ...

# %%
df.loc[:, [col for col in df.columns if df[col].dtype == float]]
# Out:
#       wave   age  age_o  d_age  importance_same_race  \
# 0      1.0  21.0   27.0    6.0                   2.0
# 1      1.0  21.0   22.0    1.0                   2.0
# 2      1.0  21.0   22.0    1.0                   2.0
# 3      1.0  21.0   23.0    2.0                   2.0
# 4      1.0  21.0   24.0    3.0                   2.0
# ...    ...   ...    ...    ...                   ...
# 8373  21.0  25.0   26.0    1.0                   1.0
# 8374  21.0  25.0   24.0    1.0                   1.0
# 8375  21.0  25.0   29.0    4.0                   1.0
# 8376  21.0  25.0   22.0    3.0                   1.0
# 8377  21.0  25.0   22.0    3.0                   1.0
#
#       importance_same_religion  pref_o_attractive  pref_o_sincere  \
# 0                          4.0               35.0            20.0
# 1                          4.0               60.0             0.0
# 2                          4.0               19.0            18.0
# ...

# %%
df.sincere.value_counts()
# Out:
# sincere
# 9.0     2393
# 8.0     2221
# 10.0    1691
# 7.0     1159
# 6.0      501
# 5.0      154
# 4.0       94
# 2.0       36
# 3.0       24
# Name: count, dtype: int64
